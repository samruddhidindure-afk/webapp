# %%
name = "samruddhi dindure"
print(name[0:len(name)])
print(name[len(name)::-1])
print(name[0:10:1])
print(name[::1])
print(name[9::1])
print(name[:17:])
print(name[0:3])
print(name[9::-1])
print(name[::])
print(name[-1::-1])
print(name[9::1])
print(name[7:11:1])
print(name[9:0:-1])
print(name[0::2])
print(name[len(name)::-2])
# Out:
# samruddhi dindure
# erudnid ihddurmas
# samruddhi
# samruddhi dindure
#  dindure
# samruddhi dindure
# sam
#  ihddurmas
# samruddhi dindure
# erudnid ihddurmas
#  dindure
# hi d
#  ihddurma
# smudidnue
# eundidums
