# %%
a = 10
print(a)
print(type(a))
print(id(a))
# Out:
# 10
# <class 'int'>
# 140723018982808

# %%
b = "hellow world"
print(b)
print(type(b))
print(id(b))
# Out:
# hellow world
# <class 'str'>
# 2008293911408

# %%
print(a)
print(b)
print(type(a),type(b))
# Out:
# 10
# hellow world
# <class 'int'> <class 'str'>
