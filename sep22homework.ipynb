# %%
name = "samruddhi"

print(name[0],name[-1])
print(name[0],name[len(name)-1])
print(name[0+0],name[-2+1])
print(name[-1+1],name[1*-1])
print(name[1-1],name[-5+4])
print(name[False],name[-True])
print(name[0+0],name[-1+0])
print(name[-2%2],name[ -True])
print(name[not True],name[-1-0])
print(name[0*1],name[-2+1])
# Out:
# s i
# s i
# s i
# s i
# s i
# s i
# s i
# s i
# s i
# s i
